# %%
# Length of a Number 
# ---> Distruction of the number,the toatl number of times the digits are destroyed itself is the length of the number 
# ---> Count how many times the while loop is running 

# Write a program that takes a number as input and outputs the length of the number..

n=3721 # Initialisation of the number 
count=0

while(n!=0): # while loop to count the number of n
    r=n%10 # Extraction of the number which is get by the reminder
    n=n//10 # Distrcution of the number 
    count=count+1 # Increasing the count after every cycle 

print(count)
# Out:
# 4

# %%
# Claculate the digit sum of the given number 

n=3721 # Initialisation of the number
ans=0

while(n!=0): 
    r=n%10 # Extraction of the number which is get by the reminder
    n=n//10 # Distrcution of the number 
    ans=ans+r # Adding the digit to the answer
print(ans)
# Out:
# 13

# %%
# Product of the digits of a number

n=3721 # Initialisation of the number 
ans=1  

while (n!=0):
    r=n%10 # Extraction of the number which is get by the reminder
    n=n//10 # Distribution of the number
    ans=ans*r # Multiplying the digit with the answer
print(ans)
# Out:
# 42

# %%
#Digit separatly from the number
n=3721  # Initialisation of the number

while(n!=0): 
    r=n%10 # Extraction of the number which is get by the reminder
    n=n//10 # Distrcution of the number 
    ans=ans*r 

print(r)
# Out:
# 3

# %%
# Reverse of a number : uses the concept of distruction of the number with construction of the number

# print the digits of the number in reverse order
n=int(input("Enter a number: ")) # Initialisation of the number
rev=0

while(n!=0):
    r=n%10 # Extraction of the number which is get by the reminder
    n=n//10 # Distrcution of the number
    rev=rev*10 # Socket Creation 
    rev=rev+r # Placement of the digit in the socket

print(rev)
# Out:
# 987654321
